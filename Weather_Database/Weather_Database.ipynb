# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 735

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count += 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]       
        city_description = city_weather["weather"][0]["description"]
        
        # Append the city information into the city_data list
        city_data.append({"City": city.title(),
                         "Lat": city_lat,
                         "Lng": city_lng,
                         "Max Temp": city_max_temp,
                         "Humidity": city_humidity,
                         "Cloudiness": city_clouds,
                         "Wind Speed": city_wind,
                         "Country": city_country,
                         "Current Description": city_description})
    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | samusu
# City not found. Skipping...
# Processing Record 2 of Set 1 | atka
# City not found. Skipping...
# Processing Record 3 of Set 1 | khatanga
# Processing Record 4 of Set 1 | kapaa
# Processing Record 5 of Set 1 | punta arenas
# Processing Record 6 of Set 1 | ushuaia
# Processing Record 7 of Set 1 | bluff
# Processing Record 8 of Set 1 | atuona
# Processing Record 9 of Set 1 | saint george
# Processing Record 10 of Set 1 | jatai
# Processing Record 11 of Set 1 | oistins
# Processing Record 12 of Set 1 | cape town
# Processing Record 13 of Set 1 | jamestown
# Processing Record 14 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 15 of Set 1 | tuktoyaktuk
# Processing Record 16 of Set 1 | upernavik
# Processing Record 17 of Set 1 | butaritari
# Processing Record 18 of Set 1 | portland
# Processing Record 19 of Set 1 | kimbe
# Processing Record 20 of Set 1 | vaini
# Processing Record 21 of Set 1 | tasiilaq
# Processing Record 22 of Set 1 | mataura
# Processing Record 23 of Set 1 | bethel
# Processing Record 24 of Set 1 | carnarvon
# Processing Record 25 of Set 1 | palabuhanratu
# City not found. Skipping...
# Processing Record 26 of Set 1 | kenora
# Processing Record 27 of Set 1 | castro
# Processing Record 28 of Set 1 | avarua
# Processing Record 29 of Set 1 | lasa
# Processing Record 30 of Set 1 | alugan
# Processing Record 31 of Set 1 | college
# Processing Record 32 of Set 1 | cherskiy
# Processing Record 33 of Set 1 | makakilo city
# Processing Record 34 of Set 1 | bambous virieux
# Processing Record 35 of Set 1 | kvarkeno
# Processing Record 36 of Set 1 | aklavik
# Processing Record 37 of Set 1 | busselton
# Processing Record 38 of Set 1 | chokurdakh
# Processing Record 39 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 40 of Set 1 | saint-philippe
# Processing Record 41 of Set 1 | vostok
# Processing Record 42 of Set 1 | lompoc
# Processing Record 43 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 44 of Set 1 | zhigansk
# Processing Record 45 of Set 1 | verkhnyaya inta
# Processing Record 46 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 47 of Set 1 | chuy
# Processing Record 48 of Set 1 | clyde river
# Processing Record 49 of Set 1 | lewistown
# Processing Record 50 of Set 1 | berlevag
# Processing Record 52 of Set 2 | klaksvik
# Processing Record 53 of Set 2 | milton
# Processing Record 54 of Set 2 | hithadhoo
# Processing Record 55 of Set 2 | hermanus
# Processing Record 56 of Set 2 | iquitos
# Processing Record 57 of Set 2 | roald
# Processing Record 58 of Set 2 | tuatapere
# Processing Record 59 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 60 of Set 2 | arraial do cabo
# Processing Record 61 of Set 2 | oranjemund
# Processing Record 62 of Set 2 | los llanos de aridane
# Processing Record 63 of Set 2 | haines junction
# Processing Record 64 of Set 2 | rawson
# Processing Record 65 of Set 2 | marienburg
# Processing Record 66 of Set 2 | adamovka
# Processing Record 67 of Set 2 | puerto ayora
# Processing Record 68 of Set 2 | nikolskoye
# Processing Record 69 of Set 2 | the valley
# Processing Record 70 of Set 2 | ambilobe
# Processing Record 71 of Set 2 | alofi
# Processing Record 72 of Set 2 | hualmay
# Processing Record 73 of Set 2 | half moon bay
# Processing Record 74 of Set 2 | cabo san lucas
# Processing Record 75 of Set 2 | nanortalik
# Processing Record 76 of Set 2 | nur
# Processing Record 77 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 78 of Set 2 | port-cartier
# Processing Record 79 of Set 2 | bredasdorp
# Processing Record 80 of Set 2 | saldanha
# Processing Record 81 of Set 2 | alausi
# Processing Record 82 of Set 2 | vardo
# Processing Record 83 of Set 2 | port-de-bouc
# Processing Record 84 of Set 2 | qaanaaq
# Processing Record 85 of Set 2 | altamont
# Processing Record 86 of Set 2 | dikson
# Processing Record 87 of Set 2 | buraydah
# Processing Record 88 of Set 2 | duz
# City not found. Skipping...
# Processing Record 89 of Set 2 | lardos
# Processing Record 90 of Set 2 | rikitea
# Processing Record 91 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 92 of Set 2 | ust-ishim
# Processing Record 93 of Set 2 | lebu
# Processing Record 94 of Set 2 | anadyr
# Processing Record 95 of Set 2 | banda aceh
# Processing Record 96 of Set 2 | kapfenberg
# Processing Record 97 of Set 2 | mar del plata
# Processing Record 98 of Set 2 | sitka
# Processing Record 99 of Set 2 | batsfjord
# Processing Record 100 of Set 2 | sept-iles
# Processing Record 101 of Set 2 | mishan
# Processing Record 103 of Set 3 | arlit
# Processing Record 104 of Set 3 | new norfolk
# Processing Record 105 of Set 3 | hilo
# Processing Record 106 of Set 3 | katsuura
# Processing Record 107 of Set 3 | volga
# Processing Record 108 of Set 3 | meridian
# Processing Record 109 of Set 3 | tautira
# Processing Record 110 of Set 3 | tiksi
# Processing Record 111 of Set 3 | sorvag
# City not found. Skipping...
# Processing Record 112 of Set 3 | pemberton
# Processing Record 113 of Set 3 | walvis bay
# Processing Record 114 of Set 3 | souillac
# Processing Record 115 of Set 3 | saleaula
# City not found. Skipping...
# Processing Record 116 of Set 3 | santiago de las vegas
# Processing Record 117 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 118 of Set 3 | canchungo
# Processing Record 119 of Set 3 | rocha
# Processing Record 120 of Set 3 | plouzane
# Processing Record 121 of Set 3 | xining
# Processing Record 122 of Set 3 | mahanoro
# Processing Record 123 of Set 3 | petropavlovsk-kamchatskiy
# Processing Record 124 of Set 3 | florianopolis
# Processing Record 125 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 126 of Set 3 | barrow
# Processing Record 127 of Set 3 | saskylakh
# Processing Record 128 of Set 3 | pepel
# Processing Record 129 of Set 3 | provideniya
# Processing Record 130 of Set 3 | sinnamary
# Processing Record 131 of Set 3 | gravdal
# Processing Record 132 of Set 3 | norman wells
# Processing Record 133 of Set 3 | puerto escondido
# Processing Record 134 of Set 3 | hobart
# Processing Record 135 of Set 3 | hibbing
# Processing Record 136 of Set 3 | albany
# Processing Record 137 of Set 3 | dokri
# Processing Record 138 of Set 3 | kruisfontein
# Processing Record 139 of Set 3 | leningradskiy
# Processing Record 140 of Set 3 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 141 of Set 3 | ponta do sol
# Processing Record 142 of Set 3 | pisco
# Processing Record 143 of Set 3 | cidreira
# Processing Record 144 of Set 3 | bubaque
# Processing Record 145 of Set 3 | notre-dame-du-lac
# Processing Record 146 of Set 3 | camacha
# Processing Record 147 of Set 3 | lorengau
# Processing Record 148 of Set 3 | alice springs
# Processing Record 149 of Set 3 | huai yot
# Processing Record 150 of Set 3 | margate
# Processing Record 151 of Set 3 | yeniseysk
# Processing Record 152 of Set 3 | kidodi
# Processing Record 154 of Set 4 | hami
# Processing Record 155 of Set 4 | louisbourg
# City not found. Skipping...
# Processing Record 156 of Set 4 | kouroussa
# Processing Record 157 of Set 4 | valle hermoso
# Processing Record 158 of Set 4 | san patricio
# Processing Record 159 of Set 4 | umzimvubu
# City not found. Skipping...
# Processing Record 160 of Set 4 | chernyshevskiy
# Processing Record 161 of Set 4 | kahului
# Processing Record 162 of Set 4 | severo-kurilsk
# Processing Record 163 of Set 4 | sobolevo
# Processing Record 164 of Set 4 | lavrentiya
# Processing Record 165 of Set 4 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 166 of Set 4 | guadalajara
# Processing Record 167 of Set 4 | omsukchan
# Processing Record 168 of Set 4 | tafresh
# Processing Record 169 of Set 4 | segezha
# Processing Record 170 of Set 4 | valparai
# Processing Record 171 of Set 4 | chalmette
# Processing Record 172 of Set 4 | ancud
# Processing Record 173 of Set 4 | kaitangata
# Processing Record 174 of Set 4 | yellowknife
# Processing Record 175 of Set 4 | sorong
# Processing Record 176 of Set 4 | bac lieu
# Processing Record 177 of Set 4 | paamiut
# Processing Record 178 of Set 4 | kavaratti
# Processing Record 179 of Set 4 | hunza
# City not found. Skipping...
# Processing Record 180 of Set 4 | kuche
# City not found. Skipping...
# Processing Record 181 of Set 4 | cabedelo
# Processing Record 182 of Set 4 | quatre cocos
# Processing Record 183 of Set 4 | luorong
# Processing Record 184 of Set 4 | umm lajj
# Processing Record 185 of Set 4 | pemangkat
# Processing Record 186 of Set 4 | nemuro
# Processing Record 187 of Set 4 | inyonga
# Processing Record 188 of Set 4 | shyryayeve
# Processing Record 189 of Set 4 | la ronge
# Processing Record 190 of Set 4 | ilulissat
# Processing Record 191 of Set 4 | narsaq
# Processing Record 192 of Set 4 | kazerun
# Processing Record 193 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 194 of Set 4 | torres
# Processing Record 195 of Set 4 | lyubinskiy
# Processing Record 196 of Set 4 | canavieiras
# Processing Record 197 of Set 4 | warqla
# City not found. Skipping...
# Processing Record 198 of Set 4 | bilibino
# Processing Record 199 of Set 4 | gushi
# Processing Record 200 of Set 4 | ostrovnoy
# Processing Record 201 of Set 4 | brae
# Processing Record 202 of Set 4 | wenatchee
# Processing Record 203 of Set 4 | gat
# Processing Record 205 of Set 5 | ribeira grande
# Processing Record 206 of Set 5 | nyzhni sirohozy
# Processing Record 207 of Set 5 | georgetown
# Processing Record 208 of Set 5 | ust-tsilma
# Processing Record 209 of Set 5 | sao filipe
# Processing Record 210 of Set 5 | temaraia
# City not found. Skipping...
# Processing Record 211 of Set 5 | abha
# Processing Record 212 of Set 5 | kodiak
# Processing Record 213 of Set 5 | beringovskiy
# Processing Record 214 of Set 5 | adrar
# Processing Record 215 of Set 5 | deputatskiy
# Processing Record 216 of Set 5 | iqaluit
# Processing Record 217 of Set 5 | innisfail
# Processing Record 218 of Set 5 | havre-saint-pierre
# Processing Record 219 of Set 5 | tres lagoas
# Processing Record 220 of Set 5 | lazaro cardenas
# Processing Record 221 of Set 5 | caravelas
# Processing Record 222 of Set 5 | bullhead city
# Processing Record 223 of Set 5 | labuhan
# Processing Record 224 of Set 5 | camargo
# Processing Record 225 of Set 5 | ahuimanu
# Processing Record 226 of Set 5 | itarema
# Processing Record 227 of Set 5 | sur
# Processing Record 228 of Set 5 | gravelbourg
# Processing Record 229 of Set 5 | prince rupert
# Processing Record 230 of Set 5 | vao
# Processing Record 231 of Set 5 | vestmanna
# Processing Record 232 of Set 5 | bairiki
# Processing Record 233 of Set 5 | lulea
# Processing Record 234 of Set 5 | kupang
# Processing Record 235 of Set 5 | luau
# Processing Record 236 of Set 5 | mullaitivu
# City not found. Skipping...
# Processing Record 237 of Set 5 | belaya gora
# Processing Record 238 of Set 5 | mogadishu
# Processing Record 239 of Set 5 | broken hill
# Processing Record 240 of Set 5 | aden
# Processing Record 241 of Set 5 | labutta
# City not found. Skipping...
# Processing Record 242 of Set 5 | verkhnevilyuysk
# Processing Record 243 of Set 5 | gornopravdinsk
# Processing Record 244 of Set 5 | sao miguel
# Processing Record 245 of Set 5 | homer
# Processing Record 246 of Set 5 | mayumba
# Processing Record 247 of Set 5 | kavieng
# Processing Record 248 of Set 5 | port alfred
# Processing Record 249 of Set 5 | esperance
# Processing Record 250 of Set 5 | lolua
# City not found. Skipping...
# Processing Record 251 of Set 5 | mahebourg
# Processing Record 252 of Set 5 | codrington
# Processing Record 253 of Set 5 | nyimba
# Processing Record 254 of Set 5 | awjilah
# Processing Record 256 of Set 6 | egvekinot
# Processing Record 257 of Set 6 | northam
# Processing Record 258 of Set 6 | sao francisco de paula
# Processing Record 259 of Set 6 | pevek
# Processing Record 260 of Set 6 | port lincoln
# Processing Record 261 of Set 6 | luanda
# Processing Record 262 of Set 6 | mount gambier
# Processing Record 263 of Set 6 | thompson
# Processing Record 264 of Set 6 | longyearbyen
# Processing Record 265 of Set 6 | bengkulu
# Processing Record 266 of Set 6 | saint-joseph
# Processing Record 267 of Set 6 | tual
# Processing Record 268 of Set 6 | nabire
# Processing Record 269 of Set 6 | artyk
# City not found. Skipping...
# Processing Record 270 of Set 6 | tazovskiy
# Processing Record 271 of Set 6 | pagegiai
# Processing Record 272 of Set 6 | key west
# Processing Record 273 of Set 6 | bannu
# Processing Record 274 of Set 6 | sao joao da barra
# Processing Record 275 of Set 6 | yanam
# Processing Record 276 of Set 6 | naze
# Processing Record 277 of Set 6 | santander
# Processing Record 278 of Set 6 | heidelberg
# Processing Record 279 of Set 6 | ahipara
# Processing Record 280 of Set 6 | chara
# Processing Record 281 of Set 6 | esfahan
# Processing Record 282 of Set 6 | progreso
# Processing Record 283 of Set 6 | broome
# Processing Record 284 of Set 6 | alberdi
# Processing Record 285 of Set 6 | arrecife
# Processing Record 286 of Set 6 | longlac
# City not found. Skipping...
# Processing Record 287 of Set 6 | lac du bonnet
# Processing Record 288 of Set 6 | rorvik
# Processing Record 289 of Set 6 | faanui
# Processing Record 290 of Set 6 | makhachkala
# Processing Record 291 of Set 6 | mana
# Processing Record 292 of Set 6 | mungwi
# Processing Record 293 of Set 6 | olinda
# Processing Record 294 of Set 6 | grand gaube
# Processing Record 295 of Set 6 | alexandria
# Processing Record 296 of Set 6 | porgera
# Processing Record 297 of Set 6 | moerai
# Processing Record 298 of Set 6 | waharoa
# Processing Record 299 of Set 6 | talnakh
# Processing Record 300 of Set 6 | kang
# Processing Record 301 of Set 6 | port elizabeth
# Processing Record 302 of Set 6 | kamenskoye
# City not found. Skipping...
# Processing Record 303 of Set 6 | kitimat
# Processing Record 304 of Set 6 | tikapur
# Processing Record 305 of Set 6 | hervey bay
# Processing Record 307 of Set 7 | mitu
# Processing Record 308 of Set 7 | laguna
# Processing Record 309 of Set 7 | puerto lopez
# Processing Record 310 of Set 7 | muroto
# Processing Record 311 of Set 7 | vila franca do campo
# Processing Record 312 of Set 7 | hammerfest
# Processing Record 313 of Set 7 | troitsko-pechorsk
# Processing Record 314 of Set 7 | tadine
# Processing Record 315 of Set 7 | coquimbo
# Processing Record 316 of Set 7 | byron bay
# Processing Record 317 of Set 7 | atbasar
# Processing Record 318 of Set 7 | salalah
# Processing Record 319 of Set 7 | mount isa
# Processing Record 320 of Set 7 | port hardy
# Processing Record 321 of Set 7 | taoudenni
# Processing Record 322 of Set 7 | hit
# Processing Record 323 of Set 7 | shenjiamen
# Processing Record 324 of Set 7 | dingle
# Processing Record 325 of Set 7 | pacific grove
# Processing Record 326 of Set 7 | micheweni
# Processing Record 327 of Set 7 | kuching
# Processing Record 328 of Set 7 | noumea
# Processing Record 329 of Set 7 | bissora
# Processing Record 330 of Set 7 | aksu
# Processing Record 331 of Set 7 | shubarshi
# Processing Record 332 of Set 7 | boende
# Processing Record 333 of Set 7 | komsomolskiy
# Processing Record 334 of Set 7 | wajid
# Processing Record 335 of Set 7 | san matias
# Processing Record 336 of Set 7 | kidal
# Processing Record 337 of Set 7 | wuda
# Processing Record 338 of Set 7 | geraldton
# Processing Record 339 of Set 7 | sibolga
# Processing Record 340 of Set 7 | sarahan
# Processing Record 341 of Set 7 | zyryanovsk
# Processing Record 342 of Set 7 | madang
# Processing Record 343 of Set 7 | porosozero
# Processing Record 344 of Set 7 | tura
# Processing Record 345 of Set 7 | nantucket
# Processing Record 346 of Set 7 | fortuna
# Processing Record 347 of Set 7 | lunenburg
# Processing Record 348 of Set 7 | husavik
# Processing Record 349 of Set 7 | ixtapa
# Processing Record 350 of Set 7 | kaniama
# Processing Record 351 of Set 7 | tampilisan
# Processing Record 352 of Set 7 | tatawin
# Processing Record 353 of Set 7 | airai
# Processing Record 354 of Set 7 | ijaki
# City not found. Skipping...
# Processing Record 355 of Set 7 | houma
# Processing Record 356 of Set 7 | andenes
# Processing Record 358 of Set 8 | osterburg
# Processing Record 359 of Set 8 | santa rosa de viterbo
# Processing Record 360 of Set 8 | dalbandin
# Processing Record 361 of Set 8 | evensk
# Processing Record 362 of Set 8 | kochevo
# Processing Record 363 of Set 8 | waingapu
# Processing Record 364 of Set 8 | seoul
# Processing Record 365 of Set 8 | xushan
# Processing Record 366 of Set 8 | port blair
# Processing Record 367 of Set 8 | wanning
# Processing Record 368 of Set 8 | avera
# Processing Record 369 of Set 8 | puksoozero
# Processing Record 370 of Set 8 | nizhniy kuranakh
# Processing Record 371 of Set 8 | lebedinyy
# Processing Record 372 of Set 8 | madison
# Processing Record 373 of Set 8 | tynda
# Processing Record 374 of Set 8 | gizo
# Processing Record 375 of Set 8 | east london
# Processing Record 376 of Set 8 | pangnirtung
# Processing Record 377 of Set 8 | okhotsk
# Processing Record 378 of Set 8 | saint anthony
# Processing Record 379 of Set 8 | kumluca
# Processing Record 380 of Set 8 | havelock
# Processing Record 381 of Set 8 | jiehu
# Processing Record 382 of Set 8 | harnoli
# Processing Record 383 of Set 8 | naryan-mar
# Processing Record 384 of Set 8 | hasaki
# Processing Record 385 of Set 8 | raudeberg
# Processing Record 386 of Set 8 | kerteh
# City not found. Skipping...
# Processing Record 387 of Set 8 | bosaso
# Processing Record 388 of Set 8 | marcona
# City not found. Skipping...
# Processing Record 389 of Set 8 | mobile
# Processing Record 390 of Set 8 | harper
# Processing Record 391 of Set 8 | juneau
# Processing Record 392 of Set 8 | gazanjyk
# Processing Record 393 of Set 8 | codajas
# Processing Record 394 of Set 8 | turbat
# Processing Record 395 of Set 8 | hofn
# Processing Record 396 of Set 8 | sembe
# Processing Record 397 of Set 8 | bereda
# Processing Record 398 of Set 8 | bajo baudo
# City not found. Skipping...
# Processing Record 399 of Set 8 | tocache
# Processing Record 400 of Set 8 | rungata
# City not found. Skipping...
# Processing Record 401 of Set 8 | kibiti
# Processing Record 402 of Set 8 | ayan
# Processing Record 403 of Set 8 | sernur
# Processing Record 404 of Set 8 | kangaatsiaq
# Processing Record 405 of Set 8 | pitimbu
# Processing Record 406 of Set 8 | fort madison
# Processing Record 407 of Set 8 | copiapo
# Processing Record 409 of Set 9 | pineville
# Processing Record 410 of Set 9 | uaua
# Processing Record 411 of Set 9 | catamarca
# Processing Record 412 of Set 9 | sri aman
# Processing Record 413 of Set 9 | hambantota
# Processing Record 414 of Set 9 | tomatlan
# Processing Record 415 of Set 9 | cap malheureux
# Processing Record 416 of Set 9 | san cristobal
# Processing Record 417 of Set 9 | panguna
# Processing Record 418 of Set 9 | coihaique
# Processing Record 419 of Set 9 | sakakah
# Processing Record 420 of Set 9 | jacqueville
# Processing Record 421 of Set 9 | victoria
# Processing Record 422 of Set 9 | chardara
# Processing Record 423 of Set 9 | tasbuget
# City not found. Skipping...
# Processing Record 424 of Set 9 | hirara
# Processing Record 425 of Set 9 | jawa
# Processing Record 426 of Set 9 | vestmannaeyjar
# Processing Record 427 of Set 9 | puri
# Processing Record 428 of Set 9 | bonthe
# Processing Record 429 of Set 9 | sharjah
# Processing Record 430 of Set 9 | helena
# Processing Record 431 of Set 9 | loukhi
# Processing Record 432 of Set 9 | mehamn
# Processing Record 433 of Set 9 | palmer
# Processing Record 434 of Set 9 | gurupa
# Processing Record 435 of Set 9 | daru
# Processing Record 436 of Set 9 | ufa
# Processing Record 437 of Set 9 | faya
# Processing Record 438 of Set 9 | ostersund
# Processing Record 439 of Set 9 | harrismith
# Processing Record 440 of Set 9 | viligili
# City not found. Skipping...
# Processing Record 441 of Set 9 | bekwai
# Processing Record 442 of Set 9 | cheuskiny
# City not found. Skipping...
# Processing Record 443 of Set 9 | waddan
# Processing Record 444 of Set 9 | korbach
# Processing Record 445 of Set 9 | quelimane
# Processing Record 446 of Set 9 | maceio
# Processing Record 447 of Set 9 | manaia
# Processing Record 448 of Set 9 | chapais
# Processing Record 449 of Set 9 | baker city
# Processing Record 450 of Set 9 | usinsk
# Processing Record 451 of Set 9 | bathsheba
# Processing Record 452 of Set 9 | tocopilla
# Processing Record 453 of Set 9 | eldikan
# City not found. Skipping...
# Processing Record 454 of Set 9 | dunedin
# Processing Record 455 of Set 9 | kalmunai
# Processing Record 456 of Set 9 | mirnyy
# Processing Record 457 of Set 9 | pringsewu
# Processing Record 458 of Set 9 | luderitz
# Processing Record 460 of Set 10 | ternate
# Processing Record 461 of Set 10 | tessalit
# Processing Record 462 of Set 10 | lata
# Processing Record 463 of Set 10 | mecca
# Processing Record 464 of Set 10 | wajima
# Processing Record 465 of Set 10 | huron
# Processing Record 466 of Set 10 | esna
# Processing Record 467 of Set 10 | marsh harbour
# Processing Record 468 of Set 10 | warrnambool
# Processing Record 469 of Set 10 | jacareacanga
# Processing Record 470 of Set 10 | kilindoni
# Processing Record 471 of Set 10 | mafinga
# Processing Record 472 of Set 10 | necochea
# Processing Record 473 of Set 10 | nakama
# Processing Record 474 of Set 10 | isangel
# Processing Record 475 of Set 10 | mutsamudu
# City not found. Skipping...
# Processing Record 476 of Set 10 | guerrero negro
# Processing Record 477 of Set 10 | padang
# Processing Record 478 of Set 10 | torbay
# Processing Record 479 of Set 10 | goderich
# Processing Record 480 of Set 10 | agucadoura
# Processing Record 481 of Set 10 | constitucion
# Processing Record 482 of Set 10 | jinxiang
# Processing Record 483 of Set 10 | batagay-alyta
# Processing Record 484 of Set 10 | korla
# Processing Record 485 of Set 10 | nuuk
# Processing Record 486 of Set 10 | qingdao
# Processing Record 487 of Set 10 | kozlovo
# Processing Record 488 of Set 10 | rameshki
# Processing Record 489 of Set 10 | san luis
# Processing Record 490 of Set 10 | henties bay
# Processing Record 491 of Set 10 | poum
# Processing Record 492 of Set 10 | planadas
# Processing Record 493 of Set 10 | nome
# Processing Record 494 of Set 10 | mergui
# City not found. Skipping...
# Processing Record 495 of Set 10 | pasni
# Processing Record 496 of Set 10 | bontang
# Processing Record 497 of Set 10 | ust-nera
# Processing Record 498 of Set 10 | kodinsk
# Processing Record 499 of Set 10 | taylor
# Processing Record 500 of Set 10 | shache
# Processing Record 501 of Set 10 | jayanca
# Processing Record 502 of Set 10 | kulhudhuffushi
# Processing Record 503 of Set 10 | auki
# Processing Record 504 of Set 10 | fairbanks
# Processing Record 505 of Set 10 | paradwip
# City not found. Skipping...
# Processing Record 506 of Set 10 | skjervoy
# Processing Record 507 of Set 10 | vila velha
# Processing Record 508 of Set 10 | boralday
# Processing Record 509 of Set 10 | marzuq
# Processing Record 511 of Set 11 | leshukonskoye
# Processing Record 512 of Set 11 | mayo
# Processing Record 513 of Set 11 | sammamish
# Processing Record 514 of Set 11 | port-gentil
# Processing Record 515 of Set 11 | kawalu
# Processing Record 516 of Set 11 | lagoa
# Processing Record 517 of Set 11 | birao
# Processing Record 518 of Set 11 | buin
# Processing Record 519 of Set 11 | praia
# Processing Record 520 of Set 11 | pozhva
# Processing Record 521 of Set 11 | san quintin
# Processing Record 522 of Set 11 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 523 of Set 11 | westport
# Processing Record 524 of Set 11 | pozo colorado
# Processing Record 525 of Set 11 | sisimiut
# Processing Record 526 of Set 11 | skagastrond
# City not found. Skipping...
# Processing Record 527 of Set 11 | taunggyi
# Processing Record 528 of Set 11 | comodoro rivadavia
# Processing Record 529 of Set 11 | manzil salim
# Processing Record 530 of Set 11 | mitchell
# Processing Record 531 of Set 11 | flin flon
# Processing Record 532 of Set 11 | flinders
# Processing Record 533 of Set 11 | sawtell
# Processing Record 534 of Set 11 | yeppoon
# Processing Record 535 of Set 11 | fomboni
# Processing Record 536 of Set 11 | ust-ilimsk
# Processing Record 537 of Set 11 | haverfordwest
# Processing Record 538 of Set 11 | sault sainte marie
# Processing Record 539 of Set 11 | abalak
# Processing Record 540 of Set 11 | ashington
# Processing Record 541 of Set 11 | cutzamala
# City not found. Skipping...
# Processing Record 542 of Set 11 | olenino
# Processing Record 543 of Set 11 | varhaug
# Processing Record 544 of Set 11 | gorontalo
# Processing Record 545 of Set 11 | fulton
# Processing Record 546 of Set 11 | bargal
# City not found. Skipping...
# Processing Record 547 of Set 11 | oktyabrskoye
# Processing Record 548 of Set 11 | minas
# Processing Record 549 of Set 11 | belyye berega
# Processing Record 550 of Set 11 | nyrob
# Processing Record 551 of Set 11 | solnechnyy
# Processing Record 552 of Set 11 | salacgriva
# Processing Record 553 of Set 11 | takoradi
# Processing Record 554 of Set 11 | nishihara
# Processing Record 555 of Set 11 | qaqortoq
# Processing Record 556 of Set 11 | hamilton
# Processing Record 557 of Set 11 | babu
# Processing Record 558 of Set 11 | bratsk
# Processing Record 559 of Set 11 | teeli
# Processing Record 560 of Set 11 | kununurra
# Processing Record 562 of Set 12 | san angelo
# Processing Record 563 of Set 12 | petrozavodsk
# Processing Record 564 of Set 12 | san rafael
# Processing Record 565 of Set 12 | attawapiskat
# City not found. Skipping...
# Processing Record 566 of Set 12 | guadalupe victoria
# Processing Record 567 of Set 12 | pryazha
# Processing Record 568 of Set 12 | azimur
# City not found. Skipping...
# Processing Record 569 of Set 12 | thinadhoo
# Processing Record 570 of Set 12 | keratea
# Processing Record 571 of Set 12 | erdenet
# Processing Record 572 of Set 12 | harrisonburg
# Processing Record 573 of Set 12 | abomey
# Processing Record 574 of Set 12 | clarence town
# Processing Record 575 of Set 12 | prado
# Processing Record 576 of Set 12 | kashima
# Processing Record 577 of Set 12 | cayenne
# Processing Record 578 of Set 12 | sedelnikovo
# City not found. Skipping...
# Processing Record 579 of Set 12 | conde
# Processing Record 580 of Set 12 | srednekolymsk
# Processing Record 581 of Set 12 | dukat
# Processing Record 582 of Set 12 | zhangjiakou
# Processing Record 583 of Set 12 | vagur
# Processing Record 584 of Set 12 | atar
# Processing Record 585 of Set 12 | milkovo
# Processing Record 586 of Set 12 | iwanai
# Processing Record 587 of Set 12 | kurashiki
# Processing Record 588 of Set 12 | ballina
# Processing Record 589 of Set 12 | halalo
# City not found. Skipping...
# Processing Record 590 of Set 12 | richards bay
# Processing Record 591 of Set 12 | mangrol
# Processing Record 592 of Set 12 | pleshanovo
# Processing Record 593 of Set 12 | manta
# Processing Record 594 of Set 12 | olafsvik
# Processing Record 595 of Set 12 | buchmany
# Processing Record 596 of Set 12 | biak
# Processing Record 597 of Set 12 | shar
# Processing Record 598 of Set 12 | hulja
# Processing Record 599 of Set 12 | west wendover
# Processing Record 600 of Set 12 | kazbegi
# City not found. Skipping...
# Processing Record 601 of Set 12 | mahadday weyne
# City not found. Skipping...
# Processing Record 602 of Set 12 | acin
# City not found. Skipping...
# Processing Record 603 of Set 12 | kranuan
# Processing Record 604 of Set 12 | burica
# City not found. Skipping...
# Processing Record 605 of Set 12 | dujuma
# City not found. Skipping...
# Processing Record 606 of Set 12 | kiknur
# Processing Record 607 of Set 12 | bulungu
# Processing Record 608 of Set 12 | kantunilkin
# Processing Record 609 of Set 12 | beirut
# Processing Record 610 of Set 12 | grindavik
# Processing Record 611 of Set 12 | el cobre
# Processing Record 613 of Set 13 | norfolk
# Processing Record 614 of Set 13 | hihifo
# City not found. Skipping...
# Processing Record 615 of Set 13 | vila
# Processing Record 616 of Set 13 | galle
# Processing Record 617 of Set 13 | kloulklubed
# Processing Record 618 of Set 13 | iquique
# Processing Record 619 of Set 13 | grand-santi
# Processing Record 620 of Set 13 | nador
# Processing Record 621 of Set 13 | usman
# Processing Record 622 of Set 13 | nagato
# Processing Record 623 of Set 13 | bethal
# Processing Record 624 of Set 13 | darnah
# Processing Record 625 of Set 13 | matara
# Processing Record 626 of Set 13 | sioux lookout
# Processing Record 627 of Set 13 | huilong
# Processing Record 628 of Set 13 | waw
# Processing Record 629 of Set 13 | quilmana
# Processing Record 630 of Set 13 | cumadcad
# Processing Record 631 of Set 13 | semirom
# Processing Record 632 of Set 13 | lodja
# Processing Record 633 of Set 13 | kontagora
# Processing Record 634 of Set 13 | sabang
# Processing Record 635 of Set 13 | sydney
# Processing Record 636 of Set 13 | rawannawi
# City not found. Skipping...
# Processing Record 637 of Set 13 | boguchany
# Processing Record 638 of Set 13 | lucapa
# Processing Record 639 of Set 13 | buzdyak
# Processing Record 640 of Set 13 | maghar
# Processing Record 641 of Set 13 | praia da vitoria
# Processing Record 642 of Set 13 | lethem
# Processing Record 643 of Set 13 | kanye
# Processing Record 644 of Set 13 | belvedere marittimo
# Processing Record 645 of Set 13 | luwingu
# Processing Record 646 of Set 13 | kampene
# Processing Record 647 of Set 13 | eureka
# Processing Record 648 of Set 13 | vereya
# Processing Record 649 of Set 13 | dubai
# Processing Record 650 of Set 13 | saint-augustin
# Processing Record 651 of Set 13 | lengshuitan
# Processing Record 652 of Set 13 | meulaboh
# Processing Record 653 of Set 13 | aykhal
# Processing Record 654 of Set 13 | tilichiki
# Processing Record 655 of Set 13 | hirtshals
# Processing Record 656 of Set 13 | ilhabela
# Processing Record 657 of Set 13 | baykit
# Processing Record 658 of Set 13 | nurota
# Processing Record 659 of Set 13 | dongsheng
# Processing Record 660 of Set 13 | braives
# Processing Record 661 of Set 13 | seminole
# Processing Record 662 of Set 13 | snyder
# Processing Record 664 of Set 14 | nisia floresta
# Processing Record 665 of Set 14 | jabinyanah
# Processing Record 666 of Set 14 | qasigiannguit
# Processing Record 667 of Set 14 | baft
# Processing Record 668 of Set 14 | havoysund
# Processing Record 669 of Set 14 | taltal
# Processing Record 670 of Set 14 | besikduzu
# Processing Record 671 of Set 14 | mulege
# Processing Record 672 of Set 14 | kasongo-lunda
# Processing Record 673 of Set 14 | caiaponia
# Processing Record 674 of Set 14 | bosobolo
# Processing Record 675 of Set 14 | karratha
# Processing Record 676 of Set 14 | consuelo
# Processing Record 677 of Set 14 | eyl
# Processing Record 678 of Set 14 | troy
# Processing Record 679 of Set 14 | manono
# Processing Record 680 of Set 14 | champerico
# Processing Record 681 of Set 14 | quetzaltepec
# City not found. Skipping...
# Processing Record 682 of Set 14 | batagay
# Processing Record 683 of Set 14 | beloha
# Processing Record 684 of Set 14 | lahij
# Processing Record 685 of Set 14 | pangkalanbuun
# Processing Record 686 of Set 14 | bindura
# Processing Record 687 of Set 14 | muros
# Processing Record 688 of Set 14 | itapetininga
# Processing Record 689 of Set 14 | slobozia
# Processing Record 690 of Set 14 | surt
# Processing Record 691 of Set 14 | fayaoue
# Processing Record 692 of Set 14 | bilma
# Processing Record 693 of Set 14 | keetmanshoop
# Processing Record 694 of Set 14 | young
# Processing Record 695 of Set 14 | kysyl-syr
# Processing Record 696 of Set 14 | sorada
# Processing Record 697 of Set 14 | samalaeulu
# City not found. Skipping...
# Processing Record 698 of Set 14 | hokitika
# Processing Record 699 of Set 14 | dourbali
# Processing Record 700 of Set 14 | launceston
# Processing Record 701 of Set 14 | glendive
# Processing Record 702 of Set 14 | namtsy
# Processing Record 703 of Set 14 | mezen
# Processing Record 704 of Set 14 | porto seguro
# Processing Record 705 of Set 14 | tawkar
# City not found. Skipping...
# Processing Record 706 of Set 14 | menongue
# Processing Record 707 of Set 14 | shingu
# Processing Record 708 of Set 14 | palu
# Processing Record 709 of Set 14 | ladan
# Processing Record 710 of Set 14 | yenagoa
# Processing Record 711 of Set 14 | asau
# Processing Record 712 of Set 14 | sisophon
# Processing Record 713 of Set 14 | balikpapan
# Processing Record 715 of Set 15 | abeche
# Processing Record 716 of Set 15 | kushima
# Processing Record 717 of Set 15 | sulangan
# Processing Record 718 of Set 15 | huambo
# Processing Record 719 of Set 15 | tawnat
# City not found. Skipping...
# Processing Record 720 of Set 15 | chau doc
# Processing Record 721 of Set 15 | grants
# Processing Record 722 of Set 15 | barawe
# City not found. Skipping...
# Processing Record 723 of Set 15 | santo domingo
# Processing Record 724 of Set 15 | ust-kalmanka
# Processing Record 725 of Set 15 | kalivai
# Processing Record 726 of Set 15 | cairns
# Processing Record 727 of Set 15 | buta
# Processing Record 728 of Set 15 | tumannyy
# City not found. Skipping...
# Processing Record 729 of Set 15 | siljan
# Processing Record 730 of Set 15 | araouane
# Processing Record 731 of Set 15 | sembakung
# Processing Record 732 of Set 15 | waipawa
# Processing Record 733 of Set 15 | astakos
# Processing Record 734 of Set 15 | nova odesa
# Processing Record 735 of Set 15 | irtyshskiy
# Processing Record 736 of Set 15 | firovo
# Processing Record 737 of Set 15 | palauig
# Processing Record 738 of Set 15 | huarmey
# Processing Record 739 of Set 15 | tabiauea
# City not found. Skipping...
# Processing Record 740 of Set 15 | marawi
# Processing Record 741 of Set 15 | sampit
# Processing Record 742 of Set 15 | eldama ravine
# Processing Record 743 of Set 15 | asfi
# Processing Record 744 of Set 15 | nadym
# Processing Record 745 of Set 15 | ashqelon
# Processing Record 746 of Set 15 | tongliao
# Processing Record 747 of Set 15 | pichayevo
# Processing Record 748 of Set 15 | khorixas
# Processing Record 749 of Set 15 | bacolod
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 671

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      Khatanga  71.9667  102.5000    -10.50        97         100
# 1         Kapaa  22.0752 -159.3190     81.10        71          75
# 2  Punta Arenas -53.1500  -70.9167     59.11        55          40
# 3       Ushuaia -54.8000  -68.3000     56.82        76           0
# 4         Bluff -46.6000  168.3333     62.80        59          76
# 5        Atuona  -9.8000 -139.0333     77.97        75          27
# 6  Saint George  37.1041 -113.5841     54.19        32           0
# 7         Jatai -17.8814  -51.7144     71.71        77          75
# 8       Oistins  13.0667  -59.5333     82.49        78          40
# 9     Cape Town -33.9258   18.4232     63.27        69           0
#
#    Wind Speed Country Current Description
# 0       13.94      RU     overcast clouds
# 1       17.27      US       broken clouds
# 2        8.05      CL    scattered clouds
# 3        3.44      AR           clear sky
# 4       11.90      NZ          light rain
# 5       17.49      PF    scattered clouds
# 6        3.44      US           clear sky
# 7        1.12      BR       broken clouds
# 8       24.16      BB    scattered clouds
# 9        1.99      ZA           clear sky

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Country', 'Current Description'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
# YOUR CODE HERE
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"] 

# Recreate the DataFrame by using the new column order
# YOUR CODE HERE
city_data_df = city_data_df[new_column_order]

# Display sample data
# YOUR CODE HERE
city_data_df.head()
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      Khatanga      RU  71.9667  102.5000    -10.50        97         100
# 1         Kapaa      US  22.0752 -159.3190     81.10        71          75
# 2  Punta Arenas      CL -53.1500  -70.9167     59.11        55          40
# 3       Ushuaia      AR -54.8000  -68.3000     56.82        76           0
# 4         Bluff      NZ -46.6000  168.3333     62.80        59          76
#
#    Wind Speed Current Description
# 0       13.94     overcast clouds
# 1       17.27       broken clouds
# 2        8.05    scattered clouds
# 3        3.44           clear sky
# 4       11.90          light rain

# %%
# Display the data types of each column by using the dtypes Pandas function
# YOUR CODE HERE
city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
# YOUR CODE HERE
output_data_file = "./WeatherPy_Database.csv"


# Export the city_data DataFrame into a CSV file
# YOUR CODE HERE
city_data_df.to_csv(output_data_file, index_label="City_ID")
